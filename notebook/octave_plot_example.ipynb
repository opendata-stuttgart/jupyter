# %%
x = linspace(0, 2*pi, 100);
y = sin(x);
plot(x, y);

# %%
x = linspace(0, 2*pi, 100);
y = sin(x);
y2 = cos(x);
plot(x, y, '+1;sin(x);', "markersize", 3, x, y2, ";cos(x);", "markersize", 2, "marker", '*');
